# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("inequality_output.csv")
data.head()
# Out:
#    Step  AgentID    Wealth Bracket   Pay
# 0     1        1  0.971133   Upper  0.08
# 1     1        2  0.984536   Upper  0.10
# 2     1        3  0.811128   Upper  0.20
# 3     1        4  1.430557   Upper  0.21
# 4     1        5  1.008291   Upper  0.20

# %%
bracs = data[data["Step"]==100]
bracs["Bracket"].value_counts()
# Out:
# Bracket
# Lower     189
# Middle     11
# Name: count, dtype: int64

# %%
data["Pay"].hist()
# Out:
# <Axes: >

# %%
final = data[data["Step"]==100]
final = list(final["Wealth"])

# %%
#uses sturges rule of bin creation
plt.hist(final, bins = int(np.log2(200) + 1))
None

# %%
min(final), max(final), sum(final)
# Out:
# (0.0, 51.129761973801465, 498.78930396834716)

# %%
X= list(range(1, 201))
y = sorted(final)

# %%
len(y), len(X)
# Out:
# (200, 200)

# %%
plt.scatter(X,y)

# %%
# Filter the DataFrame to include only rows where Step is 100
step_100_df = data.loc[data['Step'] == 100]

# Find the row with the minimum Wealth at Step 100
max_wealth_row = step_100_df.loc[step_100_df['Wealth'].idxmax()]
max_wealth_row
# Out:
# Step             100
# AgentID          134
# Wealth     51.129762
# Bracket       Middle
# Pay             0.38
# Name: 19933, dtype: object

# %%
oneagent = data.loc[data['AgentID'] == max_wealth_row["AgentID"]]


# Plot the wealth of agent 14 over time
g = plt.plot(oneagent["Step"], oneagent["Wealth"])

# %%
oneagent["Wealth"]
# Out:
# 133       2.304615
# 333       3.806183
# 533       4.953213
# 733       6.768318
# 933       7.843040
#            ...
# 19133    51.129762
# 19333    51.129762
# 19533    51.129762
# 19733    51.129762
# 19933    51.129762
# Name: Wealth, Length: 100, dtype: float64

# %%
ccdf =[]
for idx in range(len(final)): 
    if len(ccdf) == 0: 
        ccdf.append(final[idx])
    else: 
        ccdf.append(final[idx]+ccdf[-1])

# %%
plt.plot(X,ccdf)

# %%
data2 = pd.read_csv("model_output.csv")
data2.head()
# Out:
#    Unnamed: 0      Gini       Total
# 0           0  0.149418  222.088154
# 1           1  0.223660  246.169342
# 2           2  0.274991  272.341846
# 3           3  0.323659  301.144949
# 4           4  0.368730  333.316763

# %%
data2["Gini"]
# Out:
# 0     0.149418
# 1     0.223660
# 2     0.274991
# 3     0.323659
# 4     0.368730
#         ...
# 95    0.572492
# 96    0.577056
# 97    0.577082
# 98    0.567810
# 99    0.572114
# Name: Gini, Length: 100, dtype: float64

# %%
plt.plot(data2["Gini"])

# %%
x = range(1,101)
plt.scatter(x,data2["Total"])

# %%
data2["Total"]
# Out:
# 0     218.890638
# 1     230.641726
# 2     236.602236
# 3     237.437319
# 4     233.537525
#          ...
# 95    204.079206
# 96    204.079206
# 97    204.079206
# 98    204.079206
# 99    204.079206
# Name: Total, Length: 100, dtype: float64

# %%
import numpy as np
payday_array = np.random.normal(loc=0.5,
                                          scale=0.1,
                                          size=200)
innovation_array = np.random.normal(loc=1.05,
                                          scale=0.01,
                                          size=200)
x = range(1,201)
plt.hist(payday_array)
plt.hist(innovation_array)
# Out:
# (array([ 5.,  6., 17., 23., 46., 50., 33.,  9.,  8.,  3.]),
#  array([1.02508503, 1.03019659, 1.03530815, 1.04041971, 1.04553128,
#         1.05064284, 1.0557544 , 1.06086596, 1.06597752, 1.07108908,
#         1.07620065]),
#  <BarContainer object of 10 artists>)
